# %%
# !pip install gensim
import string
import re

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from gensim.parsing.preprocessing import preprocess_string

# %%
#dataset = pd.read_csv(r"C:\Users\Avita\Downloads\the_japan_times_news_dataset.csv")

# %%
dataset = pd.read_csv(r"C:\Users\Avita\Downloads\the_japan_times_news_dataset (1).csv")

# %%
dataset = list(dataset["headline"])

# %%
def replace_special_characters(input_string):
    pattern = r'[^a-zA-Z0-9\s]'
    return re.sub(pattern, "",input_string).lower()

# %%
dataset[0]
# Out:
# "Canada's pain Japan's gain as Mitsubishi buys CRJ jet"

# %%
replace_special_characters(dataset[0])
# Out:
# 'canadas pain japans gain as mitsubishi buys crj jet'

# %%
dataset_clean = [replace_special_characters(line) for line  in dataset]

# %%
dataset_clean
# Out:
# ['canadas pain japans gain as mitsubishi buys crj jet',
#  'wages must be paid in southern india ageold custom banned as slavery',
#  'meghan markles father says prince harry told him to give trump a chance',
#  'nations welcome korean summit but urge progress toward denuclearization',
#  'robust sales of switch software boosts nintendos net profit by 25 in first half',
#  'hashimoto sanctioned over 2007 tv comment',
#  'in fighting outbreaks like covid19 big pharma struggles to get out front',
#  'we know we made mistakes on 737 max boeing ceo set to tell congress',
#  'daiei allowed to reappoint management',
#  'dpj pushes 21 trillion twoyear stimulus plan',
#  'nagoya mayor blasts ldp economic policy',
#  'government wondering how to tap burgeoning ebook market',
#  'earlymodel shinkansen unit taken from closed osaka museum ultimately bound for kyoto',
#  '1 in 4 marriages in japan involved divorced person in 2015',
#  'manga about work at fukushima no 1 stirs locals ire',
# ...

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(dataset_clean)

# %%
tokenizer.word_index
# Out:
# {'to': 1,
#  'in': 2,
#  'of': 3,
#  'on': 4,
#  'for': 5,
#  'us': 6,
#  'japan': 7,
#  'the': 8,
#  'as': 9,
#  'from': 10,
#  'with': 11,
#  'and': 12,
#  'trump': 13,
#  'by': 14,
#  'says': 15,
#  'over': 16,
#  'at': 17,
#  'japanese': 18,
#  'china': 19,
#  'a': 20,
#  'but': 21,
#  'out': 22,
#  '1': 23,
#  'may': 24,
#  'after': 25,
#  'new': 26,
#  'record': 27,
#  'no': 28,
#  'abe': 29,
#  'child': 30,
#  'care': 31,
#  'calls': 32,
#  'tokyo': 33,
#  'leader': 34,
#  'children': 35,
#  'meet': 36,
#  'boost': 37,
#  'man': 38,
#  'mitsubishi': 39,
#  'be': 40,
#  'paid': 41,
#  'india': 42,
#  'harry': 43,
#  'him': 44,
#  'korean': 45,
#  'urge': 46,
#  'toward': 47,
#  'first': 48,
#  'half': 49,
#  'big': 50,
#  'front': 51,
#  'we': 52,
#  'dpj': 53,
#  'trillion': 54,
#  'policy': 55,
#  'government': 56,
#  'osaka': 57,
#  'about': 58,
#  'work': 59,
#  'workers': 60,
#  'firms': 61,
#  'water': 62,
#  'diplomacy': 63,
#  'service': 64,
#  'sector': 65,
# ...

# %%
tokenizer.texts_to_sequences(dataset_clean[5])[0]
# Out:
# []

# %%
# creating input sequence(X,y)
input_sequences = []
for line in dataset_clean:
    token_list = tokenizer.texts_to_sequences(line)
for i in range(1,len(token_list)):
    n_gram_seq = token_list[:i+1]
    input_sequences.append(n_gram_seq)

# %%
input_sequences
# Out:
# [[[], []],
#  [[], [], []],
#  [[], [], [], []],
#  [[], [], [], [], []],
#  [[], [], [], [], [], []],
#  [[], [], [], [], [], [], []],
#  [[], [], [], [], [], [], [], []],
#  [[], [], [], [], [], [], [], [], []],
#  [[], [], [], [], [], [], [], [], [], [20]],
#  [[], [], [], [], [], [], [], [], [], [20], []],
#  [[], [], [], [], [], [], [], [], [], [20], [], [20]],
#  [[], [], [], [], [], [], [], [], [], [20], [], [20], []],
#  [[], [], [], [], [], [], [], [], [], [20], [], [20], [], []],
#  [[], [], [], [], [], [], [], [], [], [20], [], [20], [], [], []],
#  [[], [], [], [], [], [], [], [], [], [20], [], [20], [], [], [], []],
#  [[], [], [], [], [], [], [], [], [], [20], [], [20], [], [], [], [], []],
#  [[], [], [], [], [], [], [], [], [], [20], [], [20], [], [], [], [], [], []],
#  [[],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [20],
#   [],
#   [20],
#   [],
#   [],
#   [],
#   [],
#   [],
#   [],
#   []],
#  [[],
#   [],
#   [],
#   [],
#   [],
# ...

# %%
max_seq_len = max(len(x) for x  in input_sequences)
print(max_seq_len)
# Out:
# 63

# %%
input_sequences_padded = pad_sequences(input_sequences, maxlen = max_seq_len)[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16256\1018031474.py in <module>
# ----> 1 input_sequences_padded = pad_sequences(input_sequences, maxlen = max_seq_len)[0]
#
# ~\anaconda3\lib\site-packages\keras\src\utils\data_utils.py in pad_sequences(sequences, maxlen, dtype, padding, truncating, value)
#    1130
#    1131         # check `trunc` has expected shape
# -> 1132         trunc = np.asarray(trunc, dtype=dtype)
#    1133         if trunc.shape[1:] != sample_shape:
#    1134             raise ValueError(
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (10,) + inhomogeneous part.

# %%
input_sequences_padded
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16256\2571200910.py in <module>
# ----> 1 input_sequences_padded
#
# NameError: name 'input_sequences_padded' is not defined

# %%
X= input_padded_sequences[:,:-1] # Predictor
y= input_padded_sequences[:,:-1] # Target
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16256\1029849229.py in <module>
# ----> 1 X= input_padded_sequences[:,:-1] # Predictor
#       2 y= input_padded_sequences[:,:-1] # Target
#
# NameError: name 'input_padded_sequences' is not defined

# %%
X[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16256\249385606.py in <module>
# ----> 1 X[0]
#
# NameError: name 'X' is not defined

# %%
y[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16256\926962809.py in <module>
# ----> 1 y[0]
#
# NameError: name 'y' is not defined

# %%
len(np.unique(y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16256\379308019.py in <module>
# ----> 1 len(np.unique(y))
#
# NameError: name 'y' is not defined

# %%
len(tokenizer.index_word)
# Out:
# 823

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16256\3563912222.py in <module>
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
y_ohe = to_categorical(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16256\2838075530.py in <module>
# ----> 1 to_categorical(y).shape
#
# NameError: name 'y' is not defined

# %%
print(X.shape)
print(y_ohe.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16256\1595462165.py in <module>
# ----> 1 print(X.shape)
#       2 print(y_ohe.shape)
#
# NameError: name 'X' is not defined

# %%
len(tokenizer.word_index.keys())
# Out:
# 823

# %% [markdown]
# # LSTM model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Embedding

# %%
model = Sequential()
model.add(Embedding(823,10))
model.add(LSTM(20))
model.add(Dense(823,activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1308\3284421949.py in <module>
#       2 model.add(Embedding(823,10))
#       3 model.add(LSTM(20))
# ----> 4 model.add(Dense(823,activation='softmax'))
#
# NameError: name 'Dense' is not defined

# %%
model.compile(optimizer='adam',loss="categorical_crossentropy",metrics=["metrics"])

# %%
model.fit(X,y_ohe,epochs=10,validation_split=0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1308\1526075988.py in <module>
# ----> 1 model.fit(X,y_ohe,epochs=10,validation_split=0.3)
#
# NameError: name 'X' is not defined

# %% [markdown]
# # Generating Sequences

# %%
start_text = "new york"
input_sequences_for_pred = []
for line in dataset_clean:
    token_list = tokenizer.texts_to_sequences(line)
for i in range(1,len(token_list)):
    n_gram_seq = token_list[:i+1]
    input_sequences.append(n_gram_seq)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1308\2348363201.py in <module>
#       1 start_text = "new york"
#       2 input_sequences = []
# ----> 3 for line in dataset_clean:
#       4     token_list = tokenizer.texts_to_sequences(line)
#       5 for i in range(1,len(token_list)):
#
# NameError: name 'dataset_clean' is not defined

# %%
input_sequences_for_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1308\410702355.py in <module>
# ----> 1 input_sequences_for_pred
#
# NameError: name 'input_sequences_for_pred' is not defined

# %%
X_test = pad_sequences(input_sequences_for_pred, maxlen=18)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1308\2933222417.py in <module>
# ----> 1 X_test = pad_sequences(input_sequences_for_pred, maxlen=18)
#
# NameError: name 'pad_sequences' is not defined

# %%
preds = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1308\3573498098.py in <module>
# ----> 1 preds = model.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
preds.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1308\3941750645.py in <module>
# ----> 1 preds.shape
#
# NameError: name 'preds' is not defined

# %%
pred_index = np.argmax(preds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1308\4086550673.py in <module>
# ----> 1 pred_index = np.argmax(preds)
#
# NameError: name 'np' is not defined

# %%
for k,v  in tokenizer.word_index.items:
